# %% [markdown]
# # Gradio Demo: hello_world
# ### The simplest possible Gradio demo. It wraps a 'Hello {name}!' function in an Interface that accepts and returns text.

# %%
# !pip install -q gradio

# %%
# Downloading files from the demo repo
import os
os.mkdir('gradio_cached_examples')
# !wget -q -O gradio_cached_examples/15 https://github.com/gradio-app/gradio/raw/main/demo/hello_world/gradio_cached_examples/15

# %%
import gradio as gr

def greet(name):
    return "Hello " + name + "!"

demo = gr.Interface(fn=greet, inputs="text", outputs="text")
    
if __name__ == "__main__":
    demo.launch()
