# %% [markdown]
# # Gradio Demo: state_cleanup

# %%
# !pip install -q gradio

# %%
# Downloading files from the demo repo
import os
os.mkdir('a')
# !wget -q -O a/1XEdlXRh9GQ.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/1XEdlXRh9GQ.webp
# !wget -q -O a/23-JSZ3SV7s.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/23-JSZ3SV7s.webp
# !wget -q -O a/CfRJ3css284.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/CfRJ3css284.webp
# !wget -q -O a/QZJjc1d7Df4.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/QZJjc1d7Df4.webp
# !wget -q -O a/RT9OiAPV6LQ.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/RT9OiAPV6LQ.webp
# !wget -q -O a/fUOeSxIf0Tg.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/fUOeSxIf0Tg.webp
# !wget -q -O a/hKC_sRDOQ1A.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/hKC_sRDOQ1A.webp
# !wget -q -O a/knRffQ8p-UY.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/knRffQ8p-UY.webp
# !wget -q -O a/l0eEZXsQht0.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/l0eEZXsQht0.webp
# !wget -q -O a/ntMC-mbcQ8Q.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/ntMC-mbcQ8Q.webp
# !wget -q -O a/xbkhaVSsT50.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/a/xbkhaVSsT50.webp
os.mkdir('admin')
# !wget -q -O admin/TcL9ccsjW-c.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/admin/TcL9ccsjW-c.webp
os.mkdir('b')
# !wget -q -O b/Pez4Lcl6x58.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/b/Pez4Lcl6x58.webp
# !wget -q -O b/sViE6fP0SO0.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/b/sViE6fP0SO0.webp
# !wget -q -O b/z0MRXZw8bbw.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/b/z0MRXZw8bbw.webp
os.mkdir('cas')
# !wget -q -O cas/0ZcsL7RL7yQ.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/cas/0ZcsL7RL7yQ.webp
# !wget -q -O cas/JM53Noc7HII.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/cas/JM53Noc7HII.webp
# !wget -q -O cas/bxZxkJVva3w.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/cas/bxZxkJVva3w.webp
# !wget -q -O cas/c-XF6y2TYCQ.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/cas/c-XF6y2TYCQ.webp
# !wget -q -O cas/saLIc9EYRwc.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/cas/saLIc9EYRwc.webp
# !wget -q -O cas/zuYtB-NySmM.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/cas/zuYtB-NySmM.webp
os.mkdir('freddy')
# !wget -q -O freddy/GW3cPaIKVgU.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/freddy/GW3cPaIKVgU.webp
# !wget -q -O freddy/M_s9n1kB62s.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/freddy/M_s9n1kB62s.webp
# !wget -q -O freddy/UH8mk3hOXPo.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/freddy/UH8mk3hOXPo.webp
# !wget -q -O freddy/fP0p0jV8uIY.webp https://github.com/gradio-app/gradio/raw/main/demo/state_cleanup/freddy/fP0p0jV8uIY.webp

# %%
from __future__ import annotations
import gradio as gr
import numpy as np
from PIL import Image
from pathlib import Path
import secrets
import shutil

current_dir = Path(__file__).parent


def generate_random_img(history: list[Image.Image], request: gr.Request):
    """Generate a random red, green, blue, orange, yellor or purple image."""
    colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 165, 0), (255, 255, 0), (128, 0, 128)]
    color = colors[np.random.randint(0, len(colors))]
    img = Image.new('RGB', (100, 100), color)
    
    user_dir: Path = current_dir / request.username # type: ignore
    user_dir.mkdir(exist_ok=True)
    path = user_dir / f"{secrets.token_urlsafe(8)}.webp"

    img.save(path)
    history.append(img)

    return img, history, history

def delete_directory(req: gr.Request):
    if not req.username:
        return
    user_dir: Path = current_dir / req.username
    shutil.rmtree(str(user_dir))

with gr.Blocks() as demo:
    gr.Markdown("""# State Cleanup Demo
                🖼️ Images are saved in a user-specific directory and deleted when the users closes the page via demo.unload.
                """)
    with gr.Row():
        with gr.Column(scale=1):
            with gr.Row():
                img = gr.Image(label="Generated Image", height=300, width=300)
            with gr.Row():
                gen = gr.Button(value="Generate")
            with gr.Row():
                history = gr.Gallery(label="Previous Generations", height=500, columns=10)
                state = gr.State(value=[], delete_callback=lambda v: print("STATE DELETED"))

    demo.load(generate_random_img, [state], [img, state, history]) 
    gen.click(generate_random_img, [state], [img, state, history])
    demo.unload(delete_directory)


demo.launch(auth=lambda user,pwd: True,
            auth_message="Enter any username and password to continue")
